# %% [markdown]
# ### 口红色号识别

# %%
方法
1.使用cv识别到人脸的唇部口红颜色
2.识别出主要的RGB颜色
3.与数据库中RGB值进行对比，选出最接近的颜色

# %%
 # 得到指定图片的主要颜色
import colorsys


def get_dominant_color(image):

    #颜色模式转换，以便输出rgb颜色值
    image = image.convert('RGBA')

    #生成缩略图，减少计算量，减小cpu压力
    image.thumbnail((200, 200))

    max_score = 0
    dominant_color = 0

    for count, (r, g, b, a) in image.getcolors(image.size[0] * image.size[1]):
        # 跳过纯黑色
        if a == 0:
            continue

        saturation = colorsys.rgb_to_hsv(r / 255.0, g / 255.0, b / 255.0)[1]

        y = min(abs(r * 2104 + g * 4130 + b * 802 + 4096 + 131072) >> 13, 235)

        y = (y - 16.0) / (235 - 16)

        # 忽略高亮色
        if y > 0.9:
            continue

        # Calculate the score, preferring highly saturated colors.
        # Add 0.1 to the saturation so we don't completely ignore grayscale
        # colors by multiplying the count by zero, but still give them a low
        # weight.
        score = (saturation + 0.1) * count

        if score > max_score:
            max_score = score
            dominant_color = (r, g, b)

    return dominant_color

# %%
from PIL import Image
test_11 = Image.open("datasets/11.png")
test_11_rgb = list(get_dominant_color(test_11))
test_11_rgb
# Out:
# [180, 55, 69]

# %%
# Out:
# (-0.5, 727.5, 265.5, -0.5)

# %%
test_22 = Image.open("datasets/22.png")
list(get_dominant_color(test_22))
# Out:
# (221, 50, 66)

# %%
# 读取口红数据库信息
import pandas as pd
lipstick = pd.read_json("datasets/lipstick.json")
brands=lipstick["brands"]
brands
# Out:
# 0    {'name': '圣罗兰', 'series': [{'name': '莹亮纯魅唇膏', ...
# 1    {'name': '香奈儿可可小姐', 'series': [{'name': '唇膏水亮'...
# 2    {'name': '迪奥', 'series': [{'name': '魅惑釉唇膏', 'l...
# 3    {'name': '美宝莲', 'series': [{'name': '绝色持久唇膏绒情哑...
# 4    {'name': '纪梵希', 'series': [{'name': '高定香榭天鹅绒唇膏...
# Name: brands, dtype: object

# %%
# 圣罗兰 Saint Laurent
# saint_laurent=brands[0]
brands[0]["series"][0]["name"]
# Out:
# '莹亮纯魅唇膏'

# %%
# saint_laurent=brands[0]


def get_lipsticks(brands):
    brands_len = len(brands)
    for i in range(brands_len):

        for j in range(len(brands[i]["series"])):

            for data in brands[i]["series"][j]["lipsticks"]:

                yield [data["id"], data["name"], data["color"], brands[i][
                    "series"][j]["name"], brands[i]["name"]]

# %%
lipstick_data=[]
for data in get_lipsticks(brands):
    lipstick_data.append(data)
lipstick_data
# Out:
# [['49', '撩骚', '#D62352', '莹亮纯魅唇膏', '圣罗兰'],
#  ['14', '一见倾心', '#DC4B41', '莹亮纯魅唇膏', '圣罗兰'],
#  ['05', '浮生若梦', '#B22146', '莹亮纯魅唇膏', '圣罗兰'],
#  ['08', '纯真梦幻', '#A25356', '莹亮纯魅唇膏', '圣罗兰'],
#  ['12', '红粉派对', '#DF3443', '莹亮纯魅唇膏', '圣罗兰'],
#  ['15', '珊瑚恋人', '#E06C68', '莹亮纯魅唇膏', '圣罗兰'],
#  ['19', '华丽转身', '#842C71', '莹亮纯魅唇膏', '圣罗兰'],
#  ['43', '唇印', '#D13C4F', '莹亮纯魅唇膏', '圣罗兰'],
#  ['04', '危情禁果', '#B71D32', '莹亮纯魅唇膏', '圣罗兰'],
#  ['06', '情窦初开', '#DE2361', '莹亮纯魅唇膏', '圣罗兰'],
#  ['09', '裸色暗恋', '#B05856', '莹亮纯魅唇膏', '圣罗兰'],
#  ['13', '邂逅巴黎', '#E06F70', '莹亮纯魅唇膏', '圣罗兰'],
#  ['16', '糖果女孩', '#CD4143', '莹亮纯魅唇膏', '圣罗兰'],
#  ['41', '告白', '#EC6A70', '莹亮纯魅唇膏', '圣罗兰'],
#  ['42', '初恋', '#EFE9DE', '莹亮纯魅唇膏', '圣罗兰'],
#  ['45', '拥吻', '#C60F2F', '莹亮纯魅唇膏', '圣罗兰'],
#  ['47', '心跳', '#BB6868', '莹亮纯魅唇膏', '圣罗兰'],
#  ['50', '约定', '#E0186B', '莹亮纯魅唇膏', '圣罗兰'],
#  ['52', '游戏', '#D45E85', '莹亮纯魅唇膏', '圣罗兰'],
#  ['44', '意外', '#C16E6F', '莹亮纯魅唇膏', '圣罗兰'],
#  ['46', '钟情', '#D1121B', '莹亮纯魅唇膏', '圣罗兰'],
#  ['48', '夜色', '#8E243E', '莹亮纯魅唇膏', '圣罗兰'],
#  ['51', '私语', '#EE7486', '莹亮纯魅唇膏', '圣罗兰'],
#  ['19', '玫红色', '#B13C79', '纯口红', '圣罗兰'],
#  ['13', '正橘色', '#BB1813', '纯口红', '圣罗兰'],
#  ['52', '星星色', '#EA4E59', '纯口红', '圣罗兰'],
#  ['01', '正红色', '#B8122B', '纯口红', '圣罗兰'],
#  ['17', '嫣粉纱丽', '#F75E70', '纯口红', '圣罗兰'],
#  ['07', '雅紫纱蓉', '#CB2276', '纯口红', '圣罗兰'],
#  ['09', '绛紫丝绒', '#C27482', '纯口红', '圣罗兰'],
#  ['11', '藕粉云罗', '#C06B72', '纯口红', '圣罗兰'],
#  ['16', '绯红香缎', '#BB444A', '纯口红', '圣罗兰'],
#  ['22', '莹亮裸粉', '#E86E9F', '纯口红', '圣罗兰'],
#  ['23', '杏色府绸', '#DE6F5C', '纯口红', '圣罗兰'],
#  ['26', '堇色流纱', '#CC6D84', '纯口红', '圣罗兰'],
#  ['36', '珊瑚雪纺', '#ED695D', '纯口红', '圣罗兰'],
#  ['49', '想你色', '#DC4D8D', '纯口红', '圣罗兰'],
#  ['51', '莹亮珊瑚橙', '#FA6C55', '纯口红', '圣罗兰'],
#  ['56', '橙红织锦', '#D9100E', '纯口红', '圣罗兰'],
#  ['59', '裸色薄纱', '#B96463', '纯口红', '圣罗兰'],
#  ['207', '珊瑚柚', '#CA4061', '纯口红', '圣罗兰'],
#  ['208', '玫红色', '#D60846', '纯口红', '圣罗兰'],
#  ['27', '纯真玫红', '#D24379', '纯口红', '圣罗兰'],
#  ['50', '前卫霓红', '#DC2923', '纯口红', '圣罗兰'],
#  ['57', '明亮裸唇', '#C7153D', '纯口红', '圣罗兰'],
#  ['58', '明亮淡紫', '#B25D84', '纯口红', '圣罗兰'],
#  ['201', '红唇印象', '#B01020', '纯口红', '圣罗兰'],
#  ['202', '疯狂玫瑰', '#9E2C2C', '纯口红', '圣罗兰'],
#  ['203', '摇滚红唇', '#940220', '纯口红', '圣罗兰'],
#  ['205', '天然浆果', '#550001', '纯口红', '圣罗兰'],
#  ['72', '', '#9A1B2F', '纯口红', '圣罗兰'],
#  ['73', '', '#CF0410', '纯口红', '圣罗兰'],
#  ['74', '', '#E0291B', '纯口红', '圣罗兰'],
#  ['211', 'DECADENT', '#E4004F', '纯口红', '圣罗兰'],
#  ['212', 'ALTERNATIVEPLUM', '#A53B4F', '纯口红', '圣罗兰'],
#  ['213', 'ORANGE SEVENTIES', '#E94138', '纯口红', '圣罗兰'],
#  ['215', 'LUST FOR PINK', '#E34E90', '纯口红', '圣罗兰'],
#  ['216', 'RED CLASH', '#DE455A', '纯口红', '圣罗兰'],
#  ['217', 'NUDE TROUBLE', '#DE455A', '纯口红', '圣罗兰'],
#  ['11', '玫色游戏', '#D51768', '莹亮纯魅美唇膏', '圣罗兰'],
#  ['3', '玫瑰轻语', '#F18885', '莹亮纯魅美唇膏', '圣罗兰'],
#  ['8', '橙色放纵', '#E52322', '莹亮纯魅美唇膏', '圣罗兰'],
#  ['4', '桃红欲望', '#DA0140', '莹亮纯魅美唇膏', '圣罗兰'],
#  ['1', '裸色幻想', '#C05B60', '莹亮纯魅美唇膏', '圣罗兰'],
#  ['2', '粉色嬉戏', '#E87593', '莹亮纯魅美唇膏', '圣罗兰'],
#  ['5', '梅色撩拨', '#630F28', '莹亮纯魅美唇膏', '圣罗兰'],
#  ['6', '红色触碰', '#CC0824', '莹亮纯魅美唇膏', '圣罗兰'],
#  ['7', '珊瑚挑逗', '#ED6D68', '莹亮纯魅美唇膏', '圣罗兰'],
#  ['9', '粉色纵情', '#E73458', '莹亮纯魅美唇膏', '圣罗兰'],
#  ['10', '绯红诱惑', '#A00F30', '莹亮纯魅美唇膏', '圣罗兰'],
#  ['12', '苺色暧昧', '#B81D3D', '莹亮纯魅美唇膏', '圣罗兰'],
#  ['12', '红绯', '#D0011E', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['46', '深红色', '#9F182C', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['50', '自然珊瑚', '#C64E5B', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['08', '唐橘', '#C41304', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['07', '蜜柚', '#CC2010', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['09', '红釉', '#D4020E', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['11', '洋红', '#D0010B', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['13', '茜色', '#CC030E', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['15', '桃红', '#D41B40', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['42', '风情橘红', '#DF294E', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['43', '玫瑰歌谣', '#E23E44', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['47', '桃红色', '#BC3250', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['48', '橙色', '#C13E30', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['49', '梅子色', '#BB325C', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['51', '玫红色', '#951E53', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['200', '丰唇唇釉', '#DC9F8F', '纯色唇釉叛逆裸唇', '圣罗兰'],
#  ['05', '樱桃情人', '#FF54A3', '莹亮绚染唇油', '圣罗兰'],
#  ['04', '粉恋玫瑰', '#FF725D', '莹亮绚染唇油', '圣罗兰'],
#  ['06', '蜜桃热恋', '#C072B5', '莹亮绚染唇油', '圣罗兰'],
#  ['07', '橙色邂逅', '#FFD0DD', '莹亮绚染唇油', '圣罗兰'],
#  ['08', '粉色憧憬', '#FF7B1E', '莹亮绚染唇油', '圣罗兰'],
#  ['05', '洋红色', '#E21949', '甜吻唇颊霜', '圣罗兰'],
#  ['01', '玫红色', '#DD2269', '甜吻唇颊霜', '圣罗兰'],
#  ['02', '樱花粉', '#E05572', '甜吻唇颊霜', '圣罗兰'],
#  ['03', '裸粉色', '#D16479', '甜吻唇颊霜', '圣罗兰'],
#  ['04', '亮橘色', '#DF4A43', '甜吻唇颊霜', '圣罗兰'],
#  ['07', '珊瑚橙', '#DC6B5D', '甜吻唇颊霜', '圣罗兰'],
#  ['08', '珊瑚粉', '#DE6A78', '甜吻唇颊霜', '圣罗兰'],
#  ['09', '珊瑚柚', '#BF7083', '甜吻唇颊霜', '圣罗兰'],
#  ['12', '摩卡色', '#AD625E', '甜吻唇颊霜', '圣罗兰'],
#  ['49', '骚动', '#D03370', '莹亮灿金唇彩', '圣罗兰'],
#  ['207', '激情', '#D11746', '莹亮灿金唇彩', '圣罗兰'],
#  ['03', '憧憬', '#D34E59', '莹亮灿金唇彩', '圣罗兰'],
#  ['15', '突然', '#AB3B48', '莹亮灿金唇彩', '圣罗兰'],
#  ['30', '甜蜜', '#DD6053', '莹亮灿金唇彩', '圣罗兰'],
#  ['203', '心跳', '#FE645A', '莹亮灿金唇彩', '圣罗兰'],
#  ['204', '意外', '#FE5B56', '莹亮灿金唇彩', '圣罗兰'],
#  ['206', '炙热', '#B80722', '莹亮灿金唇彩', '圣罗兰'],
#  ['69', '传情', '#F17365', '唇膏水亮', '香奈儿可可小姐'],
#  ['46', '自由', '#E87268', '唇膏水亮', '香奈儿可可小姐'],
#  ['122', 'CORAIL RADIEUX', '#EA4D4A', '唇膏水亮', '香奈儿可可小姐'],
#  ['97', '洒脱', '#D53D49', '唇膏水亮', '香奈儿可可小姐'],
#  ['44', '水漾纱丽', '#FD4334', '唇膏水亮', '香奈儿可可小姐'],
#  ['507', '倔强', '#E94648', '唇膏水亮', '香奈儿可可小姐'],
#  ['114', 'SHIPSHAPE', '#FF3220', '唇膏水亮', '香奈儿可可小姐'],
#  ['91', '波希米亚', '#C12A33', '唇膏水亮', '香奈儿可可小姐'],
#  ['84', '对白', '#CE1220', '唇膏水亮', '香奈儿可可小姐'],
#  ['57', '冒险', '#EB6F79', '唇膏水亮', '香奈儿可可小姐'],
#  ['116', 'MIGHTY', '#EC5193', '唇膏水亮', '香奈儿可可小姐'],
#  ['54', '卡柏男孩', '#D1918D', '唇膏水亮', '香奈儿可可小姐'],
#  ['79', '传奇', '#E86A75', '唇膏水亮', '香奈儿可可小姐'],
#  ['497', '勇敢', '#ED5A5E', '唇膏水亮', '香奈儿可可小姐'],
#  ['132', 'ROSE RAVISSANT', '#E93A5B', '唇膏水亮', '香奈儿可可小姐'],
#  ['87', '约会', '#F8657F', '唇膏水亮', '香奈儿可可小姐'],
#  ['55', '浪漫爱情', '#F14C77', '唇膏水亮', '香奈儿可可小姐'],
#  ['118', 'ENERGY', '#EB2755', '唇膏水亮', '香奈儿可可小姐'],
#  ['62', '蒙特卡罗', '#E12948', '唇膏水亮', '香奈儿可可小姐'],
#  ['134', 'RENOUVEAU', '#E7394A', '唇膏水亮', '香奈儿可可小姐'],
#  ['98', '率真', '#CC4D68', '唇膏水亮', '香奈儿可可小姐'],
#  ['60', '安蒂岗妮', '#BB395F', '唇膏水亮', '香奈儿可可小姐'],
#  ['61', '幸福时光', '#C54463', '唇膏水亮', '香奈儿可可小姐'],
#  ['90', '活泼', '#FC6E48', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['96', '古灵精怪', '#FA421C', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['182', 'VIBRANTE', '#E02E20', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['152', '隐约', '#E82F2C', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['172', 'ROUGE REBELLE', '#E40021', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['135', '谜情', '#99413D', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['99', '海盗', '#8A010D', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['176', 'INDÉPENDANTE', '#A80D1F', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['169', 'ROUGE TENTATION', '#8E2622', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['91', '吸引力', '#E45661', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['179', 'LUMINOUS', '#ED6160', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['94', '着迷', '#FC3E6E', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['138', '激昂', '#D93E5E', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['136', '悠扬', '#EF4246', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['178', 'NEW PRODIGIOUS', '#BF5363', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['158', 'VIREVOLTANTE', '#B24957', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['93', '兴奋', '#CD0043', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['165', 'ÉBLOUISSANTE', '#C82C40', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['184', 'INCANTEVOLE', '#C80F2E', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['102', '悸动', '#B20032', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['90', 'IMAGINATION', '#E1527E', '炫亮魅力唇膏', '香奈儿可可小姐'],
#  ['65', "L'ARISTOCRATICA", '#E17062', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['64', 'FIRST LIGHT', '#E84632', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['57', 'ROUGE FEU', '#BE2B24', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['66', "L'INDOMABILE", '#E1112A', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['51', '震撼', '#9E333D', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['56', 'ROUGE CHARNEL', '#B23030', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['38', '迷惑', '#892833', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['58', 'ROUGE VIE', '#822E2E', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['63', 'NIGHTFALL', '#802932', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['61', 'LA SECRÈTE', '#EC7879', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['42', '显眼', '#FE697F', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['43', '亲爱', '#FA5059', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['46', '慧黠', '#C92D38', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['37', '纵情', '#C43759', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['44', '歌剧名伶', '#F06FA5', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['50', '浪漫幻想', '#9F2F56', '炫亮魅力唇膏丝绒', '香奈儿可可小姐'],
#  ['457', '鸡尾酒', '#EB636B', '魅惑釉唇膏', '迪奥'],
#  ['487', '泡泡堂', '#EB5C97', '魅惑釉唇膏', '迪奥'],
#  ['550', '小心计', '#E47082', '魅惑釉唇膏', '迪奥'],
#  ['554', '日光浴', '#EA5344', '魅惑釉唇膏', '迪奥'],
#  ['564', '购物狂', '#E94858', '魅惑釉唇膏', '迪奥'],
#  ['577', '混日子', '#C86378', '魅惑釉唇膏', '迪奥'],
#  ['637', '热点', '#E74218', '魅惑釉唇膏', '迪奥'],
#  ['644', '生存游戏', '#EA5331', '魅惑釉唇膏', '迪奥'],
#  ['684', '人生赢家', '#E60860', '魅惑釉唇膏', '迪奥'],
#  ['740', '可乐部', '#902216', '魅惑釉唇膏', '迪奥'],
#  ['744', '花蝴蝶', '#E51E1B', '魅惑釉唇膏', '迪奥'],
#  ['794', '天生玩家', '#95358C', '魅惑釉唇膏', '迪奥'],
#  ['857', '好莱坞大咖', '#A01314', '魅惑釉唇膏', '迪奥'],
#  ['867', '红酒', '#901A32', '魅惑釉唇膏', '迪奥'],
#  ['877', '给我迪奥', '#C4032B', '魅惑釉唇膏', '迪奥'],
#  ['882', '野蛮女友', '#BB0E63', '魅惑釉唇膏', '迪奥'],
#  ['904', '黑咖啡', '#391E1D', '魅惑釉唇膏', '迪奥'],
#  ['924', '不羁', '#602227', '魅惑釉唇膏', '迪奥'],
#  ['351', '魅惑染唇蜜', '#D8707D', '魅惑染唇蜜', '迪奥'],
#  ['421', '魅惑染唇蜜', '#AD5F56', '魅惑染唇蜜', '迪奥'],
#  ['451', 'Natural Coral', '#E55461', '魅惑染唇蜜', '迪奥'],
#  ['491', '魅惑染唇蜜', '#A76165', '魅惑染唇蜜', '迪奥'],
#  ['761', 'Natural Cherry', '#E13D5D', '魅惑染唇蜜', '迪奥'],
#  ['771', 'Natural Berry', '#974249', '魅惑染唇蜜', '迪奥'],
#  ['881', 'Natural Pink', '#EC6292', '魅惑染唇蜜', '迪奥'],
#  ['028', 'Actrice', '#E83F4A', '烈艳蓝金唇膏', '迪奥'],
#  ['426', '', '#D58F7F', '烈艳蓝金唇膏', '迪奥'],
#  ['481', '', '#B76566', '烈艳蓝金唇膏', '迪奥'],
#  ['047', '迪奥小姐', '#E40068', '烈艳蓝金唇膏', '迪奥'],
#  ['781', '', '#833B43', '烈艳蓝金唇膏', '迪奥'],
#  ['060', '首映礼', '#D36179', '烈艳蓝金唇膏', '迪奥'],
#  ['080', '微笑正红', '#D91820', '烈艳蓝金唇膏', '迪奥'],
#  ['861', '', '#B52237', '烈艳蓝金唇膏', '迪奥'],
#  ['996', '', '#BD7376', '烈艳蓝金唇膏', '迪奥'],
#  ['999', '', '#A82628', '烈艳蓝金唇膏', '迪奥'],
#  ['999', 'Metallic', '#A82628', '烈艳蓝金唇膏', '迪奥'],
#  ['207', '蒙田灰', '#BBC3C2', '烈艳蓝金唇膏', '迪奥'],
#  ['277', 'Osée', '#DB7096', '烈艳蓝金唇膏', '迪奥'],
#  ['343', 'Panaréa', '#EF7C6B', '烈艳蓝金唇膏', '迪奥'],
#  ['351', 'Dansante', '#E46177', '烈艳蓝金唇膏', '迪奥'],
#  ['459', 'Charnelle', '#D1546E', '烈艳蓝金唇膏', '迪奥'],
#  ['520', 'Feel Good', '#E4003E', '烈艳蓝金唇膏', '迪奥'],
#  ['553', 'Sillage', '#DA4F4E', '烈艳蓝金唇膏', '迪奥'],
#  ['567', 'Rose en Dior', '#EA5069', '烈艳蓝金唇膏', '迪奥'],
#  ['576', 'Pretty Matte', '#F08182', '烈艳蓝金唇膏', '迪奥'],
#  ['602', '狂想', '#2E4763', '烈艳蓝金唇膏', '迪奥'],
#  ['642', 'Ready', '#EA5155', '烈艳蓝金唇膏', '迪奥'],
#  ['643', 'Stand Out', '#E84617', '烈艳蓝金唇膏', '迪奥'],
#  ['652', '珊瑚', '#ED6C7F', '烈艳蓝金唇膏', '迪奥'],
#  ['663', 'Désir', '#D0546B', '烈艳蓝金唇膏', '迪奥'],
#  ['665', 'Rêvée', '#BD5154', '烈艳蓝金唇膏', '迪奥'],
#  ['678', 'Culte', '#CC4A6B', '烈艳蓝金唇膏', '迪奥'],
#  ['746', 'Favorite', '#DC002C', '烈艳蓝金唇膏', '迪奥'],
#  ['756', 'Panache', '#E52F31', '烈艳蓝金唇膏', '迪奥'],
#  ['766', 'Rose Harpers', '#CF1D59', '烈艳蓝金唇膏', '迪奥'],
#  ['771', 'Radiant Matte', '#E96C81', '烈艳蓝金唇膏', '迪奥'],
#  ['772', 'Classic Matte', '#CB7A84', '烈艳蓝金唇膏', '迪奥'],
#  ['775', 'Hyde Park', '#E1244B', '烈艳蓝金唇膏', '迪奥'],
#  ['787', 'Exuberant Matte', '#E6699D', '烈艳蓝金唇膏', '迪奥'],
#  ['789', '痴迷', '#96518F', '烈艳蓝金唇膏', '迪奥'],
#  ['844', 'Trafalgar', '#E0262E', '烈艳蓝金唇膏', '迪奥'],
#  ['856', 'Célèbre', '#B62631', '烈艳蓝金唇膏', '迪奥'],
#  ['888', 'Strong Matte', '#EB5958', '烈艳蓝金唇膏', '迪奥'],
#  ['962', '奇葩', '#86556D', '烈艳蓝金唇膏', '迪奥'],
#  ['999', '', '#BE020D', '烈艳蓝金唇膏', '迪奥'],
#  ['999', '传奇红唇哑光', '#CC434D', '烈艳蓝金唇膏', '迪奥'],
#  ['MAT5', '', '#99163A', '绝色持久唇膏绒情哑光', '美宝莲'],
#  ['R45M', '', '#A22040', '绝色持久唇膏绒情哑光', '美宝莲'],
#  ['R41M', 'COLOR SENSATIONAL VIVID MATTE', '#C31431', '绝色持久唇膏绒情哑光', '美宝莲'],
#  ['MAT1', '', '#EC5C80', '绝色持久唇膏绒情哑光', '美宝莲'],
#  ['MAT3', '', '#EC594F', '绝色持久唇膏绒情哑光', '美宝莲'],
#  ['MAT5', '', '#F193AD', '绝色持久唇膏绒情哑光', '美宝莲'],
#  ['N103', '优雅米色', '#DF695F', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['N103', '迷人茶色', '#C74A52', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['N105', '阳光小麦', '#A82A40', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['N202', '幻想玫瑰', '#F43556', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['N204', '樱桃玫瑰', '#BE2446', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['N205', '加仑玫瑰', '#E70060', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['N304', '加州红', '#F82131', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['N306', '法式红', '#E50036', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['N303', '珊瑚红', '#FA054B', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['N302', '芭比红', '#FB2C60', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['305', '缪斯红', '#FA013D', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['201', '糖果玫瑰', '#FA6173', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['209', '明艳玫瑰', '#F60071', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['210', '大丽玫瑰', '#FF4D89', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['315', '覆盆子红', '#AC003A', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['317', '暖柿红', '#E03B35', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['307', '石榴红', '#93142F', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['301', '西瓜红', '#DF3751', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['214', '复古玫瑰', '#BB3C5A', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['323', '高雅梅', '#C53057', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['326', '勃艮第红', '#932844', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['327', '莓紫红', '#9B325A', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['324', '秀场红', '#EE4650', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['325', '圣水红', '#E11020', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['215', '橡皮裸肌', '#844452', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['329', '红色高跟鞋', '#731919', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['330', '复古提琴', '#64263F', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['331', '赤霞珠', '#58151E', '高定香榭天鹅绒唇膏（小羊皮）', '纪梵希'],
#  ['11', '御姐橘', '#BA353C', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['7', '幻想紫', '#8B2844', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['8', '暗夜莓', '#B12252', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['9', '沉睡红', '#DD485B', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['10', '帅T红', '#B53D52', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['12', '女巫红', '#B9282D', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['13', '禁忌红', '#CA292E', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['14', '鬼魅红', '#CB2D21', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['15', '夜光橘', '#D43A29', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['16', '潮女红', '#DF4541', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['18', '童话粉', '#D35C5E', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['22', '精灵粉', '#EC2663', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['23', '魔女粉', '#C62E54', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['24', '傲娇粉', '#AA2260', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['17', '乙女粉', '#DD5852', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['19', '治愈粉', '#E36476', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['20', '萝莉粉', '#EC6284', '禁忌之吻霓虹唇膏', '纪梵希'],
#  ['21', '元气粉', '#EA586F', '禁忌之吻霓虹唇膏', '纪梵希']]

# %%
import numpy as np
lipstick_data=np.array(lipstick_data)

# %%
len(lipstick_data[:,2])
# Out:
# 287

# %%
from PIL import ImageColor
lipstick_color=lipstick_data[:,2]
def get_rgb_color(lipstick_color):
    for c in lipstick_color:
        yield list(ImageColor.getrgb(c))

# %%
lipstick_colors=[]
for c in get_rgb_color(lipstick_color):
    lipstick_colors.append(c)

# %%
lipstick_colors=np.array(lipstick_colors)
lipstick_colors[0]
# Out:
# array([214,  35,  82])

# %%
test_11_rgb=np.array(test_11_rgb)
test_11_rgb
# Out:
# array([180,  55,  69])

# %%
 def get_labels(test_data):
    # 1.求最短距离
    distances = (((test_data - lipstick_colors)**2).sum(axis=1))**0.5
    # 2.排序
    nearset_index = np.argsort(distances)
    # 3.取出最近的k值
    topK_k = [lipstick_data[i] for i in nearset_index[:3]]
    return topK_k

# %%
topK_l = [lipstick_data[i] for i in nearset_index[:3]]
topK_l
# Out:
# [array(['15', '突然', '#AB3B48', '莹亮灿金唇彩', '圣罗兰'], dtype='<U29'),
#  array(['11', '御姐橘', '#BA353C', '禁忌之吻霓虹唇膏', '纪梵希'], dtype='<U29'),
#  array(['10', '帅T红', '#B53D52', '禁忌之吻霓虹唇膏', '纪梵希'], dtype='<U29')]

# %%
# 测试的图片
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.imshow(test_11)
plt.axis('off')
# Out:
# (-0.5, 727.5, 265.5, -0.5)

# %%
# 获得口红色号前三名
fig= plt.figure(1)  # 创建图表1
axs0=plt.subplot(221,facecolor='#AB3B48') 
axs1=plt.subplot(222,facecolor='#BA353C')
axs2=plt.subplot(223,facecolor='#B53D52')

# %%
## 测试2
test_22 = Image.open("datasets/22.png")
test2=np.array(list(get_dominant_color(test_22)))
test2
# Out:
# array([221,  50,  66])

# %%
get_labels(test2)
# Out:
# [array(['12', '红粉派对', '#DF3443', '莹亮纯魅唇膏', '圣罗兰'], dtype='<U29'),
#  array(['62', '蒙特卡罗', '#E12948', '唇膏水亮', '香奈儿可可小姐'], dtype='<U29'),
#  array(['43', '玫瑰歌谣', '#E23E44', '纯色唇釉叛逆裸唇', '圣罗兰'], dtype='<U29')]

# %%
plt.imshow(test_22)
plt.axis('off')
# Out:
# (-0.5, 438.5, 152.5, -0.5)

# %%
fig= plt.figure(1)  # 创建图表1
axs0=plt.subplot(221,facecolor='#DF3443') 
axs1=plt.subplot(222,facecolor='#E12948')
axs2=plt.subplot(223,facecolor='#E23E44')

# %%
# xne44.png
xne44 = Image.open("datasets/xne44.png")
xne44_rgb=np.array(list(get_dominant_color(xne44)))
plt.imshow(xne44)
plt.axis('off')
# Out:
# (-0.5, 217.5, 81.5, -0.5)

# %%
get_labels(xne44_rgb)
# Out:
# [array(['41', '告白', '#EC6A70', '莹亮纯魅唇膏', '圣罗兰'], dtype='<U29'),
#  array(['79', '传奇', '#E86A75', '唇膏水亮', '香奈儿可可小姐'], dtype='<U29'),
#  array(['7', '珊瑚挑逗', '#ED6D68', '莹亮纯魅美唇膏', '圣罗兰'], dtype='<U29')]

# %%
fig= plt.figure(1)  # 创建图表1
axs0=plt.subplot(221,facecolor='#EC6A70') 
axs1=plt.subplot(222,facecolor='#E86A75')
axs2=plt.subplot(223,facecolor='#ED6D68')
